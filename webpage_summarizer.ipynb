# %%
# !pip install -qU tiktoken langchain langchain-core langchain-ollama langchain-openai langchain-community beautifulsoup4

# %%
# !pip install langchain-experimental

# %%
# !pip install --upgrade langchain

# %%
from langchain_community.document_loaders import WebBaseLoader, PyPDFLoader
from langchain_ollama import OllamaLLM
from langchain_openai import ChatOpenAI
#from langchain.chains.combine_documents import create_stuff_document_chain
#from langchain_experimental.chains.combine_documents import create_stuff_document_chain
from langchain.chains.combine_documents import create_stuff_documents_chain

from langchain.chains.llm import LLMChain
from langchain_core.prompts import ChatPromptTemplate
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
#load the document content
loader = WebBaseLoader("https://www.nasdaq.com/articles/stocks-settle-mixed-concerns-over-trade-policy-and-fiscal-outlook")
docs = loader.load()

# %%
len(docs)
# Out:
# 1

# %%
docs[0].page_content
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nStocks Settle Mixed on Concerns Over Trade Policy and the Fiscal Outlook | Nasdaq\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to main content\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nNasdaq+\n\n\n\n\n\n\n\nWeekly Macro+\n\n\n\n\n\n\n\n\n\n\n\n\nScorecard\n\n\n\n\nMarket Activity\n\n\n\n\n\n\n\n\nU.S. Market Activity\n->\n\n\n\n\nStocks\n\n\nOptions\n\n\nETFs\n\n\nMutual Funds\n\n\nIndexes\n\n\nCryptocurrency\n\n\nCurrencies\n\n\nFixed Income\n\n\n\n                                  Trading & Market Services\n                              \n\n\nNorth American Markets\n\n\nNasdaq-100 Index\n\n\nNasdaq-100 Index Options\n\n\nMarket Data\n\n\n\n\n\n\nEuropean Markets\n->\n\n\n\n\nShares\n\n\nIndexes\n\n\nFixed Income\n\n\nOptions & Futures\n\n\nETPs
# ...

# %%
from langchain_ollama import OllamaLLM

llm = OllamaLLM(model="llama3")
llm.invoke('hi')
# Out:
# "Hi! It's nice to meet you. Is there something I can help you with, or would you like to chat?"

# %%
from langchain.chains import StuffDocumentsChain
from langchain.chains.llm import LLMChain
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "Write a consise summary of the following : \n{context}")
])
chain = create_stuff_documents_chain(llm, prompt_template)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 6
#       3 from langchain.prompts import PromptTemplate
#       4 from langchain_openai import ChatOpenAI
# ----> 6 prompt_template = ChatPromptTemplate.from_messages([
#       7     ("System", "Write a consise summary of the following : \n{context}")
#       8 ])
#       9 chain = create_stuff_documents_chain(llm, prompt_template)
#
# File c:\AIToXR\Insight_Thread\13-F_Scripts\news_feed_extraction\myenv\Lib\site-packages\langchain_core\prompts\chat.py:1167, in ChatPromptTemplate.from_messages(cls, messages, template_format)
#    1127 @classmethod
#    1128 def from_messages(
#    1129     cls,
#    1130     messages: Sequence[MessageLikeRepresentation],
#    1131     template_format: PromptTemplateFormat = "f-string",
#    1132 ) -> ChatPromptTemplate:
# ...

# %%
summary = chain.invoke({"context: docs"})
print(summary)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 summary = chain.invoke({"context: docs"})
#       2 print(summary)
#
# File c:\AIToXR\Insight_Thread\13-F_Scripts\news_feed_extraction\myenv\Lib\site-packages\langchain\chains\base.py:167, in Chain.invoke(self, input, config, **kwargs)
#     165 except BaseException as e:
#     166     run_manager.on_chain_error(e)
# --> 167     raise e
#     168 run_manager.on_chain_end(outputs)
#     170 if include_run_info:
#
# File c:\AIToXR\Insight_Thread\13-F_Scripts\news_feed_extraction\myenv\Lib\site-packages\langchain\chains\base.py:157, in Chain.invoke(self, input, config, **kwargs)
#     154 try:
#     155     self._validate_inputs(inputs)
#     156     outputs = (
# --> 157         self._call(inputs, run_manager=run_manager)
#     158         if new_arg_supported
#     159         else self._call(inputs)
# ...
